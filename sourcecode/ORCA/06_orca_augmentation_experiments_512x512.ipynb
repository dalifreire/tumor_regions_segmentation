# %% [markdown]
# # No augmentation (accuracy: 0.917 ± 0.030 / loss: 0.311 ± 0.101)

# %%
import csv
import pandas as pd 
from IPython.core.display import HTML

training_dir = "../../datasets/ORCA_512x512/training"
csv_file_path = "{}/orca_training_accuracy_loss_noaugmentation.csv".format(training_dir)
df = pd.read_csv(csv_file_path)

transformation = 'no_augmentation'
train = df.loc[(df['phase'] == 'train') & (df['augmentation'] == transformation)]
test = df.loc[(df['phase'] == 'test') & (df['augmentation'] == transformation)]

print("'{}' mean accuracy: {}".format(transformation, test['accuracy'].mean()))
print("'{}' standard deviation: {}".format(transformation, test['accuracy'].std()))
print("'{}' best loss: {}".format(transformation, test['loss'].min()))

train_best_accuracy = train[train['accuracy']==train['accuracy'].max()]
display(HTML(train_best_accuracy.to_html()))

test_best_accuracy = test[test['accuracy']==test['accuracy'].max()]
display(HTML(test_best_accuracy.to_html()))

test_best_loss = test[test['loss']==test['loss'].min()]
display(HTML(test_best_loss.to_html()))

# Performance Learning Curves: Learning curves calculated on the metric by which the model will be evaluated and selected, e.g. accuracy.
# Optimization Learning Curves: Learning curves calculated on the metric by which the parameters of the model are being optimized, e.g. loss.
df_accuracy_lines = pd.DataFrame({
    'accuracy train {:.3f} ({:.3f} ± {:.3f})'.format(train['accuracy'].max(), train['accuracy'].mean(), train['accuracy'].std()): train['accuracy'].to_numpy(),
    'accuracy test {:.3f} ({:.3f} ± {:.3f})'.format(test['accuracy'].max(), test['accuracy'].mean(), test['accuracy'].std()): test['accuracy'].to_numpy(),
    'loss train {:.3f} ({:.3f} ± {:.3f})'.format(train['loss'].min(), train['loss'].mean(), train['loss'].std()): train['loss'].to_numpy(),
    'loss test {:.3f} ({:.3f} ± {:.3f})'.format(test['loss'].min(), test['loss'].mean(), test['loss'].std()): test['loss'].to_numpy()
}, index = train['epoch'])

txt_title = "No augmentation: ({:.3f} ± {:.3f} / {:.3f} ± {:.3f})".format(test['accuracy'].mean(), test['accuracy'].std(), test['loss'].mean(), test['loss'].std())
accuracy_lines = df_accuracy_lines.plot.line(ylim=(0,1), figsize=(20,10), grid=True, xticks=range(0,401,10), title=txt_title)
accuracy_lines.plot([test_best_accuracy['epoch'].values[0]], [test_best_accuracy['accuracy'].values[0]], 'go', c='r')
accuracy_lines.plot([test_best_loss['epoch'].values[0]], [test_best_loss['loss'].values[0]], 'go', c='r')
accuracy_lines.axhline(test['accuracy'].mean(), color="red", linestyle="--")
accuracy_lines.axhline(test['loss'].mean(), color="red", linestyle="--")
#accuracy_lines.get_figure().savefig("{}/plot_200.png".format(training_dir))

#display(HTML(test_no_augmentation.to_html()))




x = pd.DataFrame(columns=('epoch', 'acc_train', 'acc_test', 'loss_train', 'loss_test'))
x['epoch'] = train['epoch'].to_numpy()
x['acc_train'] = train['accuracy'].to_numpy()
x['loss_train'] = train['loss'].to_numpy()
x['acc_test'] = test['accuracy'].to_numpy()
x['loss_test'] = test['loss'].to_numpy()
#print(x)

#print("Best accuracy: {}".format(test['accuracy'].max()))
#print("Mean accuracy: {}".format(test['accuracy'].mean()))
#print("Standard deviation: {}".format(test['accuracy'].std()))
#print("Best loss: {}".format(test['loss'].min()))
#print(test['accuracy'].size)

latex_csv_file_path = csv_file_path.replace(".csv", "__{}_latex.csv".format(transformation))
x.to_csv(latex_csv_file_path, encoding='utf-8', index=False)
# Out:
# 'no_augmentation' mean accuracy: 0.8558642588615417
# 'no_augmentation' standard deviation: 0.005818061258995137
# 'no_augmentation' best loss: 0.29980396807193754
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>augmentation</th>
#       <th>phase</th>
#       <th>epoch</th>
#       <th>loss</th>
#       <th>accuracy</th>
#       <th>date</th>
#       <th>transformations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>772</th>
#       <td>ORCA_512x512__Size-512x512_Epoch-387_Images-100_Batch-1__no_augmentation.pth</td>
#       <td>no_augmentation</td>
#       <td>train</td>
#       <td>387</td>
#       <td>0.058281</td>
#       <td>0.975286</td>
#       <td>2022-01-09 04:20:08.495946</td>
#       <td>[None]</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
# ...

# %% [markdown]
# # Color augmentation (accuracy: 0.927 ± 0.036 / loss: 0.242 ± 0.153)

# %%
import csv
import pandas as pd 
from IPython.core.display import HTML

training_dir = "../../datasets/ORCA_512x512/training"
csv_file_path = "{}/orca_training_accuracy_loss_color.csv".format(training_dir)
df = pd.read_csv(csv_file_path)

transformation = 'color_augmentation'
train = df.loc[(df['phase'] == 'train') & (df['augmentation'] == transformation)]
test = df.loc[(df['phase'] == 'test') & (df['augmentation'] == transformation)]

print("'{}' mean accuracy: {}".format(transformation, test['accuracy'].mean()))
print("'{}' standard deviation: {}".format(transformation, test['accuracy'].std()))
print("'{}' best loss: {}".format(transformation, test['loss'].min()))

train_best_accuracy = train[train['accuracy']==train['accuracy'].max()]
display(HTML(train_best_accuracy.to_html()))

test_best_accuracy = test[test['accuracy']==test['accuracy'].max()]
display(HTML(test_best_accuracy.to_html()))

test_best_loss = test[test['loss']==test['loss'].min()]
display(HTML(test_best_loss.to_html()))

# Performance Learning Curves: Learning curves calculated on the metric by which the model will be evaluated and selected, e.g. accuracy.
# Optimization Learning Curves: Learning curves calculated on the metric by which the parameters of the model are being optimized, e.g. loss.
df_accuracy_lines = pd.DataFrame({
    'accuracy train {:.3f} ({:.3f} ± {:.3f})'.format(train['accuracy'].max(), train['accuracy'].mean(), train['accuracy'].std()): train['accuracy'].to_numpy(),
    'accuracy test {:.3f} ({:.3f} ± {:.3f})'.format(test['accuracy'].max(), test['accuracy'].mean(), test['accuracy'].std()): test['accuracy'].to_numpy(),
    'loss train {:.3f} ({:.3f} ± {:.3f})'.format(train['loss'].min(), train['loss'].mean(), train['loss'].std()): train['loss'].to_numpy(),
    'loss test {:.3f} ({:.3f} ± {:.3f})'.format(test['loss'].min(), test['loss'].mean(), test['loss'].std()): test['loss'].to_numpy()
}, index = train['epoch'])

txt_title = "Color augmentation: ({:.3f} ± {:.3f} / {:.3f} ± {:.3f})".format(test['accuracy'].mean(), test['accuracy'].std(), test['loss'].mean(), test['loss'].std())
accuracy_lines = df_accuracy_lines.plot.line(ylim=(0,1), figsize=(20,10), grid=True, xticks=range(0,401,10), title=txt_title)
accuracy_lines.plot([test_best_accuracy['epoch'].values[0]], [test_best_accuracy['accuracy'].values[0]], 'go', c='r')
accuracy_lines.plot([test_best_loss['epoch'].values[0]], [test_best_loss['loss'].values[0]], 'go', c='r')
accuracy_lines.axhline(test['accuracy'].mean(), color="red", linestyle="--")
accuracy_lines.axhline(test['loss'].mean(), color="red", linestyle="--")
#accuracy_lines.get_figure().savefig("{}/plot_200.png".format(training_dir))

#display(HTML(test_no_augmentation.to_html()))




x = pd.DataFrame(columns=('epoch', 'acc_train', 'acc_test', 'loss_train', 'loss_test'))
x['epoch'] = train['epoch'].to_numpy()
x['acc_train'] = train['accuracy'].to_numpy()
x['loss_train'] = train['loss'].to_numpy()
x['acc_test'] = test['accuracy'].to_numpy()
x['loss_test'] = test['loss'].to_numpy()
#print(x)

#print("Best accuracy: {}".format(test['accuracy'].max()))
#print("Mean accuracy: {}".format(test['accuracy'].mean()))
#print("Standard deviation: {}".format(test['accuracy'].std()))
#print("Best loss: {}".format(test['loss'].min()))
#print(test['accuracy'].size)

latex_csv_file_path = csv_file_path.replace(".csv", "__{}_latex.csv".format(transformation))
x.to_csv(latex_csv_file_path, encoding='utf-8', index=False)
# Out:
# 'color_augmentation' mean accuracy: 0.8393349224090576
# 'color_augmentation' standard deviation: 0.006810455148112383
# 'color_augmentation' best loss: 0.3165914388000965
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>augmentation</th>
#       <th>phase</th>
#       <th>epoch</th>
#       <th>loss</th>
#       <th>accuracy</th>
#       <th>date</th>
#       <th>transformations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>776</th>
#       <td>ORCA_512x512__Size-512x512_Epoch-389_Images-100_Batch-1__color_augmentation.pth</td>
#       <td>color_augmentation</td>
#       <td>train</td>
#       <td>389</td>
#       <td>0.061029</td>
#       <td>0.974031</td>
#       <td>2022-01-10 10:33:30.159016</td>
#       <td>['color_transfer']</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
# ...

# %% [markdown]
# # Inpainting augmentation (accuracy: 0.935 ± 0.040 / loss: 0.202 ± 0.126)

# %%
import csv
import pandas as pd 
from IPython.core.display import HTML

training_dir = "../../datasets/ORCA_512x512/training"
csv_file_path = "{}/orca_training_accuracy_loss_inpainting.csv".format(training_dir)
df = pd.read_csv(csv_file_path)

transformation = 'inpainting_augmentation'
train = df.loc[(df['phase'] == 'train') & (df['augmentation'] == transformation)]
test = df.loc[(df['phase'] == 'test') & (df['augmentation'] == transformation)]

print("'{}' mean accuracy: {}".format(transformation, test['accuracy'].mean()))
print("'{}' standard deviation: {}".format(transformation, test['accuracy'].std()))
print("'{}' best loss: {}".format(transformation, test['loss'].min()))

train_best_accuracy = train[train['accuracy']==train['accuracy'].max()]
display(HTML(train_best_accuracy.to_html()))

test_best_accuracy = test[test['accuracy']==test['accuracy'].max()]
display(HTML(test_best_accuracy.to_html()))

test_best_loss = test[test['loss']==test['loss'].min()]
display(HTML(test_best_loss.to_html()))

# Performance Learning Curves: Learning curves calculated on the metric by which the model will be evaluated and selected, e.g. accuracy.
# Optimization Learning Curves: Learning curves calculated on the metric by which the parameters of the model are being optimized, e.g. loss.
df_accuracy_lines = pd.DataFrame({
    'accuracy train {:.3f} ({:.3f} ± {:.3f})'.format(train['accuracy'].max(), train['accuracy'].mean(), train['accuracy'].std()): train['accuracy'].to_numpy(),
    'accuracy test {:.3f} ({:.3f} ± {:.3f})'.format(test['accuracy'].max(), test['accuracy'].mean(), test['accuracy'].std()): test['accuracy'].to_numpy(),
    'loss train {:.3f} ({:.3f} ± {:.3f})'.format(train['loss'].min(), train['loss'].mean(), train['loss'].std()): train['loss'].to_numpy(),
    'loss test {:.3f} ({:.3f} ± {:.3f})'.format(test['loss'].min(), test['loss'].mean(), test['loss'].std()): test['loss'].to_numpy()
}, index = train['epoch'])

txt_title = "Color augmentation: ({:.3f} ± {:.3f} / {:.3f} ± {:.3f})".format(test['accuracy'].mean(), test['accuracy'].std(), test['loss'].mean(), test['loss'].std())
accuracy_lines = df_accuracy_lines.plot.line(ylim=(0,1), figsize=(20,10), grid=True, xticks=range(0,401,10), title=txt_title)
accuracy_lines.plot([test_best_accuracy['epoch'].values[0]], [test_best_accuracy['accuracy'].values[0]], 'go', c='r')
accuracy_lines.plot([test_best_loss['epoch'].values[0]], [test_best_loss['loss'].values[0]], 'go', c='r')
accuracy_lines.axhline(test['accuracy'].mean(), color="red", linestyle="--")
accuracy_lines.axhline(test['loss'].mean(), color="red", linestyle="--")
#accuracy_lines.get_figure().savefig("{}/plot_200.png".format(training_dir))

#display(HTML(test_no_augmentation.to_html()))




x = pd.DataFrame(columns=('epoch', 'acc_train', 'acc_test', 'loss_train', 'loss_test'))
x['epoch'] = train['epoch'].to_numpy()
x['acc_train'] = train['accuracy'].to_numpy()
x['loss_train'] = train['loss'].to_numpy()
x['acc_test'] = test['accuracy'].to_numpy()
x['loss_test'] = test['loss'].to_numpy()
#print(x)

#print("Best accuracy: {}".format(test['accuracy'].max()))
#print("Mean accuracy: {}".format(test['accuracy'].mean()))
#print("Standard deviation: {}".format(test['accuracy'].std()))
#print("Best loss: {}".format(test['loss'].min()))
#print(test['accuracy'].size)

latex_csv_file_path = csv_file_path.replace(".csv", "__{}_latex.csv".format(transformation))
x.to_csv(latex_csv_file_path, encoding='utf-8', index=False)
# Out:
# 'inpainting_augmentation' mean accuracy: 0.8530044973464239
# 'inpainting_augmentation' standard deviation: 0.007309774565396021
# 'inpainting_augmentation' best loss: 0.2998770850896835
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>augmentation</th>
#       <th>phase</th>
#       <th>epoch</th>
#       <th>loss</th>
#       <th>accuracy</th>
#       <th>date</th>
#       <th>transformations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>782</th>
#       <td>ORCA_512x512__Size-512x512_Epoch-390_Images-100_Batch-1__inpainting_augmentation_inpainting.pth</td>
#       <td>inpainting_augmentation</td>
#       <td>train</td>
#       <td>393</td>
#       <td>0.077222</td>
#       <td>0.966639</td>
#       <td>2022-01-14 10:19:46.740024</td>
#       <td>['inpainting']</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
# ...

# %% [markdown]
# # -------

# %% [markdown]
# # Geometric augmentations

# %% [markdown]
# ## Random - 4 operations (accuracy: 0.931 ± 0.038 / loss: 0.188 ± 0.132)

# %%
import csv
import pandas as pd 
from IPython.core.display import HTML

training_dir = "../../datasets/ORCA_512x512/training"
csv_file_path = "{}/orca_training_accuracy_loss_geo.csv".format(training_dir)
df = pd.read_csv(csv_file_path)

transformation = 'random_4_operations_geo'
train = df.loc[(df['phase'] == 'train') & (df['augmentation'] == transformation)]
test = df.loc[(df['phase'] == 'test') & (df['augmentation'] == transformation)]

print("'{}' mean accuracy: {}".format(transformation, test['accuracy'].mean()))
print("'{}' standard deviation: {}".format(transformation, test['accuracy'].std()))
print("'{}' best loss: {}".format(transformation, test['loss'].min()))

train_best_accuracy = train[train['accuracy']==train['accuracy'].max()]
display(HTML(train_best_accuracy.to_html()))

test_best_accuracy = test[test['accuracy']==test['accuracy'].max()]
display(HTML(test_best_accuracy.to_html()))

test_best_loss = test[test['loss']==test['loss'].min()]
display(HTML(test_best_loss.to_html()))

# Performance Learning Curves: Learning curves calculated on the metric by which the model will be evaluated and selected, e.g. accuracy.
# Optimization Learning Curves: Learning curves calculated on the metric by which the parameters of the model are being optimized, e.g. loss.
df_accuracy_lines = pd.DataFrame({
    'accuracy train {:.3f} ({:.3f} ± {:.3f})'.format(train['accuracy'].max(), train['accuracy'].mean(), train['accuracy'].std()): train['accuracy'].to_numpy(),
    'accuracy test {:.3f} ({:.3f} ± {:.3f})'.format(test['accuracy'].max(), test['accuracy'].mean(), test['accuracy'].std()): test['accuracy'].to_numpy(),
    'loss train {:.3f} ({:.3f} ± {:.3f})'.format(train['loss'].min(), train['loss'].mean(), train['loss'].std()): train['loss'].to_numpy(),
    'loss test {:.3f} ({:.3f} ± {:.3f})'.format(test['loss'].min(), test['loss'].mean(), test['loss'].std()): test['loss'].to_numpy()
}, index = train['epoch'])

txt_title = "Random: geometric transformations ({:.3f} ± {:.3f} / {:.3f} ± {:.3f})".format(test['accuracy'].mean(), test['accuracy'].std(), test['loss'].mean(), test['loss'].std())
accuracy_lines = df_accuracy_lines.plot.line(ylim=(0,1), figsize=(20,10), grid=True, xticks=range(0,401,10), title=txt_title)
accuracy_lines.plot([test_best_accuracy['epoch'].values[0]], [test_best_accuracy['accuracy'].values[0]], 'go', c='r')
accuracy_lines.plot([test_best_loss['epoch'].values[0]], [test_best_loss['loss'].values[0]], 'go', c='r')
accuracy_lines.axhline(test['accuracy'].mean(), color="red", linestyle="--")
accuracy_lines.axhline(test['loss'].mean(), color="red", linestyle="--")
#accuracy_lines.get_figure().savefig("{}/plot_200.png".format(training_dir))

#display(HTML(test_no_augmentation.to_html()))




x = pd.DataFrame(columns=('epoch', 'acc_train', 'acc_test', 'loss_train', 'loss_test'))
x['epoch'] = train['epoch'].to_numpy()
x['acc_train'] = train['accuracy'].to_numpy()
x['loss_train'] = train['loss'].to_numpy()
x['acc_test'] = test['accuracy'].to_numpy()
x['loss_test'] = test['loss'].to_numpy()
#print(x)

#print("Best accuracy: {}".format(test['accuracy'].max()))
#print("Mean accuracy: {}".format(test['accuracy'].mean()))
#print("Standard deviation: {}".format(test['accuracy'].std()))
#print("Best loss: {}".format(test['loss'].min()))
#print(test['accuracy'].size)

latex_csv_file_path = csv_file_path.replace(".csv", "__{}_512x512_latex.csv".format(transformation))
x.to_csv(latex_csv_file_path, encoding='utf-8', index=False)
# Out:
# 'random_4_operations_geo' mean accuracy: 0.8573089038848878
# 'random_4_operations_geo' standard deviation: 0.006733770337887975
# 'random_4_operations_geo' best loss: 0.2976039051264525
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>augmentation</th>
#       <th>phase</th>
#       <th>epoch</th>
#       <th>loss</th>
#       <th>accuracy</th>
#       <th>date</th>
#       <th>transformations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>798</th>
#       <td>ORCA_512x512__Size-512x512_Epoch-400_Images-100_Batch-1__random_4_operations_geo.pth</td>
#       <td>random_4_operations_geo</td>
#       <td>train</td>
#       <td>400</td>
#       <td>0.100112</td>
#       <td>0.957319</td>
#       <td>2022-01-11 12:29:57.857447</td>
#       <td>[None 'horizontal_flip' 'vertical_flip' 'rotation' 'transpose']</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %% [markdown]
# # Distortion augmentations

# %% [markdown]
# ## Random - 2 operations (accuracy: 0.937 ± 0.040 / loss: 0.168 ± 0.115)

# %%
import csv
import pandas as pd 
from IPython.core.display import HTML

training_dir = "../../datasets/ORCA_512x512/training"
csv_file_path = "{}/orca_training_accuracy_loss_distortion.csv".format(training_dir)
df = pd.read_csv(csv_file_path)

transformation = 'random_2_operations'
train = df.loc[(df['phase'] == 'train') & (df['augmentation'] == transformation)]
test = df.loc[(df['phase'] == 'test') & (df['augmentation'] == transformation)]

print("'{}' mean accuracy: {}".format(transformation, test['accuracy'].mean()))
print("'{}' standard deviation: {}".format(transformation, test['accuracy'].std()))
print("'{}' best loss: {}".format(transformation, test['loss'].min()))

train_best_accuracy = train[train['accuracy']==train['accuracy'].max()]
display(HTML(train_best_accuracy.to_html()))

test_best_accuracy = test[test['accuracy']==test['accuracy'].max()]
display(HTML(test_best_accuracy.to_html()))

test_best_loss = test[test['loss']==test['loss'].min()]
display(HTML(test_best_loss.to_html()))

# Performance Learning Curves: Learning curves calculated on the metric by which the model will be evaluated and selected, e.g. accuracy.
# Optimization Learning Curves: Learning curves calculated on the metric by which the parameters of the model are being optimized, e.g. loss.
df_accuracy_lines = pd.DataFrame({
    'accuracy train {:.3f} ({:.3f} ± {:.3f})'.format(train['accuracy'].max(), train['accuracy'].mean(), train['accuracy'].std()): train['accuracy'].to_numpy(),
    'accuracy test {:.3f} ({:.3f} ± {:.3f})'.format(test['accuracy'].max(), test['accuracy'].mean(), test['accuracy'].std()): test['accuracy'].to_numpy(),
    'loss train {:.3f} ({:.3f} ± {:.3f})'.format(train['loss'].min(), train['loss'].mean(), train['loss'].std()): train['loss'].to_numpy(),
    'loss test {:.3f} ({:.3f} ± {:.3f})'.format(test['loss'].min(), test['loss'].mean(), test['loss'].std()): test['loss'].to_numpy()
}, index = train['epoch'])

txt_title = "Random: distortion transformations ({:.3f} ± {:.3f} / {:.3f} ± {:.3f})".format(test['accuracy'].mean(), test['accuracy'].std(), test['loss'].mean(), test['loss'].std())
accuracy_lines = df_accuracy_lines.plot.line(ylim=(0,1), figsize=(20,10), grid=True, xticks=range(0,401,10), title=txt_title)
accuracy_lines.plot([test_best_accuracy['epoch'].values[0]], [test_best_accuracy['accuracy'].values[0]], 'go', c='r')
accuracy_lines.plot([test_best_loss['epoch'].values[0]], [test_best_loss['loss'].values[0]], 'go', c='r')
accuracy_lines.axhline(test['accuracy'].mean(), color="red", linestyle="--")
accuracy_lines.axhline(test['loss'].mean(), color="red", linestyle="--")
#accuracy_lines.get_figure().savefig("{}/plot_200.png".format(training_dir))

#display(HTML(test_no_augmentation.to_html()))




x = pd.DataFrame(columns=('epoch', 'acc_train', 'acc_test', 'loss_train', 'loss_test'))
x['epoch'] = train['epoch'].to_numpy()
x['acc_train'] = train['accuracy'].to_numpy()
x['loss_train'] = train['loss'].to_numpy()
x['acc_test'] = test['accuracy'].to_numpy()
x['loss_test'] = test['loss'].to_numpy()
#print(x)

#print("Best accuracy: {}".format(test['accuracy'].max()))
#print("Mean accuracy: {}".format(test['accuracy'].mean()))
#print("Standard deviation: {}".format(test['accuracy'].std()))
#print("Best loss: {}".format(test['loss'].min()))
#print(test['accuracy'].size)

latex_csv_file_path = csv_file_path.replace(".csv", "__{}_latex.csv".format(transformation))
x.to_csv(latex_csv_file_path, encoding='utf-8', index=False)
# Out:
# 'random_2_operations' mean accuracy: 0.8580592946599898
# 'random_2_operations' standard deviation: 0.009625944843520012
# 'random_2_operations' best loss: 0.2978871501982212
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>augmentation</th>
#       <th>phase</th>
#       <th>epoch</th>
#       <th>loss</th>
#       <th>accuracy</th>
#       <th>date</th>
#       <th>transformations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>792</th>
#       <td>ORCA_512x512__Size-512x512_Epoch-398_Images-100_Batch-1__random_2_operations_distortion.pth</td>
#       <td>random_2_operations</td>
#       <td>train</td>
#       <td>398</td>
#       <td>0.1128</td>
#       <td>0.952231</td>
#       <td>2022-01-12 11:10:11.576010</td>
#       <td>[None 'grid_distortion' 'optical_distortion']</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
# ...

# %% [markdown]
# # All transformations

# %% [markdown]
# ## Standard - 9 operations (accuracy: 0.934 ± 0.039 / loss: 0.171 ± 0.112)

# %%
import csv
import pandas as pd 
from IPython.core.display import HTML

training_dir = "../../datasets/ORCA_512x512/training"
csv_file_path = "{}/orca_training_accuracy_loss_all.csv".format(training_dir)
df = pd.read_csv(csv_file_path)

transformation = 'standard_9_operations'
train = df.loc[(df['phase'] == 'train') & (df['augmentation'] == transformation)]
test = df.loc[(df['phase'] == 'test') & (df['augmentation'] == transformation)]

print("'{}' mean accuracy: {}".format(transformation, test['accuracy'].mean()))
print("'{}' standard deviation: {}".format(transformation, test['accuracy'].std()))
print("'{}' best loss: {}".format(transformation, test['loss'].min()))

train_best_accuracy = train[train['accuracy']==train['accuracy'].max()]
display(HTML(train_best_accuracy.to_html()))

test_best_accuracy = test[test['accuracy']==test['accuracy'].max()]
display(HTML(test_best_accuracy.to_html()))

test_best_loss = test[test['loss']==test['loss'].min()]
display(HTML(test_best_loss.to_html()))

# Performance Learning Curves: Learning curves calculated on the metric by which the model will be evaluated and selected, e.g. accuracy.
# Optimization Learning Curves: Learning curves calculated on the metric by which the parameters of the model are being optimized, e.g. loss.
df_accuracy_lines = pd.DataFrame({
    'accuracy train {:.3f} ({:.3f} ± {:.3f})'.format(train['accuracy'].max(), train['accuracy'].mean(), train['accuracy'].std()): train['accuracy'].to_numpy(),
    'accuracy test {:.3f} ({:.3f} ± {:.3f})'.format(test['accuracy'].max(), test['accuracy'].mean(), test['accuracy'].std()): test['accuracy'].to_numpy(),
    'loss train {:.3f} ({:.3f} ± {:.3f})'.format(train['loss'].min(), train['loss'].mean(), train['loss'].std()): train['loss'].to_numpy(),
    'loss test {:.3f} ({:.3f} ± {:.3f})'.format(test['loss'].min(), test['loss'].mean(), test['loss'].std()): test['loss'].to_numpy()
}, index = train['epoch'])

txt_title = "Standard: all transformations (9) ({:.3f} ± {:.3f} / {:.3f} ± {:.3f})".format(test['accuracy'].mean(), test['accuracy'].std(), test['loss'].mean(), test['loss'].std())
accuracy_lines = df_accuracy_lines.plot.line(ylim=(0,1), figsize=(20,10), grid=True, xticks=range(0,401,10), title=txt_title)
accuracy_lines.plot([test_best_accuracy['epoch'].values[0]], [test_best_accuracy['accuracy'].values[0]], 'go', c='r')
accuracy_lines.plot([test_best_loss['epoch'].values[0]], [test_best_loss['loss'].values[0]], 'go', c='r')
accuracy_lines.axhline(test['accuracy'].mean(), color="red", linestyle="--")
accuracy_lines.axhline(test['loss'].mean(), color="red", linestyle="--")
#accuracy_lines.get_figure().savefig("{}/plot_200.png".format(training_dir))

#display(HTML(test_no_augmentation.to_html()))




x = pd.DataFrame(columns=('epoch', 'acc_train', 'acc_test', 'loss_train', 'loss_test'))
x['epoch'] = train['epoch'].to_numpy()
x['acc_train'] = train['accuracy'].to_numpy()
x['loss_train'] = train['loss'].to_numpy()
x['acc_test'] = test['accuracy'].to_numpy()
x['loss_test'] = test['loss'].to_numpy()
#print(x)

#print("Best accuracy: {}".format(test['accuracy'].max()))
#print("Mean accuracy: {}".format(test['accuracy'].mean()))
#print("Standard deviation: {}".format(test['accuracy'].std()))
#print("Best loss: {}".format(test['loss'].min()))
#print(test['accuracy'].size)

latex_csv_file_path = csv_file_path.replace(".csv", "__{}_512x512_latex.csv".format(transformation))
x.to_csv(latex_csv_file_path, encoding='utf-8', index=False)
# Out:
# 'standard_9_operations' mean accuracy: 0.854796063423157
# 'standard_9_operations' standard deviation: 0.009239580563028704
# 'standard_9_operations' best loss: 0.2891803151369095
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>augmentation</th>
#       <th>phase</th>
#       <th>epoch</th>
#       <th>loss</th>
#       <th>accuracy</th>
#       <th>date</th>
#       <th>transformations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>764</th>
#       <td>ORCA_512x512__Size-512x512_Epoch-380_Images-100_Batch-1__standard_9_operations_all.pth</td>
#       <td>standard_9_operations</td>
#       <td>train</td>
#       <td>383</td>
#       <td>0.116103</td>
#       <td>0.95114</td>
#       <td>2022-01-15 01:35:05.143518</td>
# ...

# %% [markdown]
# ## Standard - 8 operations (accuracy: 0.xxx ± 0.xxx / loss: 0.xxx ± 0.xxx)

# %%
import csv
import pandas as pd 
from IPython.core.display import HTML

training_dir = "../../datasets/ORCA_512x512/training"
csv_file_path = "{}/orca_training_accuracy_loss_all.csv".format(training_dir)
df = pd.read_csv(csv_file_path)

transformation = 'standard_8_operations'
train = df.loc[(df['phase'] == 'train') & (df['augmentation'] == transformation)]
test = df.loc[(df['phase'] == 'test') & (df['augmentation'] == transformation)]

print("'{}' mean accuracy: {}".format(transformation, test['accuracy'].mean()))
print("'{}' standard deviation: {}".format(transformation, test['accuracy'].std()))
print("'{}' best loss: {}".format(transformation, test['loss'].min()))

train_best_accuracy = train[train['accuracy']==train['accuracy'].max()]
display(HTML(train_best_accuracy.to_html()))

test_best_accuracy = test[test['accuracy']==test['accuracy'].max()]
display(HTML(test_best_accuracy.to_html()))

test_best_loss = test[test['loss']==test['loss'].min()]
display(HTML(test_best_loss.to_html()))

# Performance Learning Curves: Learning curves calculated on the metric by which the model will be evaluated and selected, e.g. accuracy.
# Optimization Learning Curves: Learning curves calculated on the metric by which the parameters of the model are being optimized, e.g. loss.
df_accuracy_lines = pd.DataFrame({
    'accuracy train {:.3f} ({:.3f} ± {:.3f})'.format(train['accuracy'].max(), train['accuracy'].mean(), train['accuracy'].std()): train['accuracy'].to_numpy(),
    'accuracy test {:.3f} ({:.3f} ± {:.3f})'.format(test['accuracy'].max(), test['accuracy'].mean(), test['accuracy'].std()): test['accuracy'].to_numpy(),
    'loss train {:.3f} ({:.3f} ± {:.3f})'.format(train['loss'].min(), train['loss'].mean(), train['loss'].std()): train['loss'].to_numpy(),
    'loss test {:.3f} ({:.3f} ± {:.3f})'.format(test['loss'].min(), test['loss'].mean(), test['loss'].std()): test['loss'].to_numpy()
}, index = train['epoch'])

txt_title = "Standard: all transformations (8) ({:.3f} ± {:.3f} / {:.3f} ± {:.3f})".format(test['accuracy'].mean(), test['accuracy'].std(), test['loss'].mean(), test['loss'].std())
accuracy_lines = df_accuracy_lines.plot.line(ylim=(0,1), figsize=(20,10), grid=True, xticks=range(0,401,10), title=txt_title)
accuracy_lines.plot([test_best_accuracy['epoch'].values[0]], [test_best_accuracy['accuracy'].values[0]], 'go', c='r')
accuracy_lines.plot([test_best_loss['epoch'].values[0]], [test_best_loss['loss'].values[0]], 'go', c='r')
accuracy_lines.axhline(test['accuracy'].mean(), color="red", linestyle="--")
accuracy_lines.axhline(test['loss'].mean(), color="red", linestyle="--")
#accuracy_lines.get_figure().savefig("{}/plot_200.png".format(training_dir))

#display(HTML(test_no_augmentation.to_html()))




x = pd.DataFrame(columns=('epoch', 'acc_train', 'acc_test', 'loss_train', 'loss_test'))
x['epoch'] = train['epoch'].to_numpy()
x['acc_train'] = train['accuracy'].to_numpy()
x['loss_train'] = train['loss'].to_numpy()
x['acc_test'] = test['accuracy'].to_numpy()
x['loss_test'] = test['loss'].to_numpy()
#print(x)

#print("Best accuracy: {}".format(test['accuracy'].max()))
#print("Mean accuracy: {}".format(test['accuracy'].mean()))
#print("Standard deviation: {}".format(test['accuracy'].std()))
#print("Best loss: {}".format(test['loss'].min()))
#print(test['accuracy'].size)

latex_csv_file_path = csv_file_path.replace(".csv", "__{}_512x512_latex.csv".format(transformation))
x.to_csv(latex_csv_file_path, encoding='utf-8', index=False)
# Out:
# 'standard_8_operations' mean accuracy: 0.8525324028015138
# 'standard_8_operations' standard deviation: 0.008290895351425163
# 'standard_8_operations' best loss: 0.30650171235203744
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>augmentation</th>
#       <th>phase</th>
#       <th>epoch</th>
#       <th>loss</th>
#       <th>accuracy</th>
#       <th>date</th>
#       <th>transformations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3192</th>
#       <td>ORCA_512x512__Size-512x512_Epoch-390_Images-100_Batch-1__standard_8_operations_all.pth</td>
#       <td>standard_8_operations</td>
#       <td>train</td>
#       <td>397</td>
#       <td>0.113087</td>
#       <td>0.952121</td>
#       <td>2022-01-19 02:42:12.625104</td>
#       <td>[None 'horizontal_flip' 'vertical_flip' 'rotation' 'transpose' 'grid_distortion' 'optical_distortion' 'color_transfer' 'inpainting']</td>
# ...

# %% [markdown]
# ## Random - 9 operations (accuracy: 0.922 ± 0.042 / loss: 0.188 ± 0.110)

# %%
import csv
import pandas as pd 
from IPython.core.display import HTML

training_dir = "../../datasets/ORCA_512x512/training"
csv_file_path = "{}/orca_training_accuracy_loss_all.csv".format(training_dir)
df = pd.read_csv(csv_file_path)

transformation = 'random_9_operations'
train = df.loc[(df['phase'] == 'train') & (df['augmentation'] == transformation)]
test = df.loc[(df['phase'] == 'test') & (df['augmentation'] == transformation)]

print("'{}' mean accuracy: {}".format(transformation, test['accuracy'].mean()))
print("'{}' standard deviation: {}".format(transformation, test['accuracy'].std()))
print("'{}' best loss: {}".format(transformation, test['loss'].min()))

train_best_accuracy = train[train['accuracy']==train['accuracy'].max()]
display(HTML(train_best_accuracy.to_html()))

test_best_accuracy = test[test['accuracy']==test['accuracy'].max()]
display(HTML(test_best_accuracy.to_html()))

test_best_loss = test[test['loss']==test['loss'].min()]
display(HTML(test_best_loss.to_html()))

# Performance Learning Curves: Learning curves calculated on the metric by which the model will be evaluated and selected, e.g. accuracy.
# Optimization Learning Curves: Learning curves calculated on the metric by which the parameters of the model are being optimized, e.g. loss.
df_accuracy_lines = pd.DataFrame({
    'accuracy train {:.3f} ({:.3f} ± {:.3f})'.format(train['accuracy'].max(), train['accuracy'].mean(), train['accuracy'].std()): train['accuracy'].to_numpy(),
    'accuracy test {:.3f} ({:.3f} ± {:.3f})'.format(test['accuracy'].max(), test['accuracy'].mean(), test['accuracy'].std()): test['accuracy'].to_numpy(),
    'loss train {:.3f} ({:.3f} ± {:.3f})'.format(train['loss'].min(), train['loss'].mean(), train['loss'].std()): train['loss'].to_numpy(),
    'loss test {:.3f} ({:.3f} ± {:.3f})'.format(test['loss'].min(), test['loss'].mean(), test['loss'].std()): test['loss'].to_numpy()
}, index = train['epoch'])

txt_title = "Standard: all transformations (9) ({:.3f} ± {:.3f} / {:.3f} ± {:.3f})".format(test['accuracy'].mean(), test['accuracy'].std(), test['loss'].mean(), test['loss'].std())
accuracy_lines = df_accuracy_lines.plot.line(ylim=(0,1), figsize=(20,10), grid=True, xticks=range(0,401,10), title=txt_title)
accuracy_lines.plot([test_best_accuracy['epoch'].values[0]], [test_best_accuracy['accuracy'].values[0]], 'go', c='r')
accuracy_lines.plot([test_best_loss['epoch'].values[0]], [test_best_loss['loss'].values[0]], 'go', c='r')
accuracy_lines.axhline(test['accuracy'].mean(), color="red", linestyle="--")
accuracy_lines.axhline(test['loss'].mean(), color="red", linestyle="--")
#accuracy_lines.get_figure().savefig("{}/plot_200.png".format(training_dir))

#display(HTML(test_no_augmentation.to_html()))




x = pd.DataFrame(columns=('epoch', 'acc_train', 'acc_test', 'loss_train', 'loss_test'))
x['epoch'] = train['epoch'].to_numpy()
x['acc_train'] = train['accuracy'].to_numpy()
x['loss_train'] = train['loss'].to_numpy()
x['acc_test'] = test['accuracy'].to_numpy()
x['loss_test'] = test['loss'].to_numpy()
#print(x)

#print("Best accuracy: {}".format(test['accuracy'].max()))
#print("Mean accuracy: {}".format(test['accuracy'].mean()))
#print("Standard deviation: {}".format(test['accuracy'].std()))
#print("Best loss: {}".format(test['loss'].min()))
#print(test['accuracy'].size)

latex_csv_file_path = csv_file_path.replace(".csv", "__{}_512x512_latex.csv".format(transformation))
x.to_csv(latex_csv_file_path, encoding='utf-8', index=False)
# Out:
# 'random_9_operations' mean accuracy: 0.8486962835311889
# 'random_9_operations' standard deviation: 0.00931656051265325
# 'random_9_operations' best loss: 0.3045146758854389
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>augmentation</th>
#       <th>phase</th>
#       <th>epoch</th>
#       <th>loss</th>
#       <th>accuracy</th>
#       <th>date</th>
#       <th>transformations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1558</th>
#       <td>ORCA_512x512__Size-512x512_Epoch-380_Images-100_Batch-1__random_9_operations_all.pth</td>
#       <td>random_9_operations</td>
#       <td>train</td>
#       <td>380</td>
#       <td>0.178835</td>
#       <td>0.924312</td>
#       <td>2022-01-15 21:36:15.969159</td>
# ...

# %% [markdown]
# ## Random - 8 operations (accuracy: 0.xxx ± 0.xxx / loss: 0.xxx ± 0.xxx)

# %%
import csv
import pandas as pd 
from IPython.core.display import HTML

training_dir = "../../datasets/ORCA_512x512/training"
csv_file_path = "{}/orca_training_accuracy_loss_all.csv".format(training_dir)
df = pd.read_csv(csv_file_path)

transformation = 'random_8_operations'
train = df.loc[(df['phase'] == 'train') & (df['augmentation'] == transformation)]
test = df.loc[(df['phase'] == 'test') & (df['augmentation'] == transformation)]

print("'{}' mean accuracy: {}".format(transformation, test['accuracy'].mean()))
print("'{}' standard deviation: {}".format(transformation, test['accuracy'].std()))
print("'{}' best loss: {}".format(transformation, test['loss'].min()))

train_best_accuracy = train[train['accuracy']==train['accuracy'].max()]
display(HTML(train_best_accuracy.to_html()))

test_best_accuracy = test[test['accuracy']==test['accuracy'].max()]
display(HTML(test_best_accuracy.to_html()))

test_best_loss = test[test['loss']==test['loss'].min()]
display(HTML(test_best_loss.to_html()))

# Performance Learning Curves: Learning curves calculated on the metric by which the model will be evaluated and selected, e.g. accuracy.
# Optimization Learning Curves: Learning curves calculated on the metric by which the parameters of the model are being optimized, e.g. loss.
df_accuracy_lines = pd.DataFrame({
    'accuracy train {:.3f} ({:.3f} ± {:.3f})'.format(train['accuracy'].max(), train['accuracy'].mean(), train['accuracy'].std()): train['accuracy'].to_numpy(),
    'accuracy test {:.3f} ({:.3f} ± {:.3f})'.format(test['accuracy'].max(), test['accuracy'].mean(), test['accuracy'].std()): test['accuracy'].to_numpy(),
    'loss train {:.3f} ({:.3f} ± {:.3f})'.format(train['loss'].min(), train['loss'].mean(), train['loss'].std()): train['loss'].to_numpy(),
    'loss test {:.3f} ({:.3f} ± {:.3f})'.format(test['loss'].min(), test['loss'].mean(), test['loss'].std()): test['loss'].to_numpy()
}, index = train['epoch'])

txt_title = "Random: all transformations (8) ({:.3f} ± {:.3f} / {:.3f} ± {:.3f})".format(test['accuracy'].mean(), test['accuracy'].std(), test['loss'].mean(), test['loss'].std())
accuracy_lines = df_accuracy_lines.plot.line(ylim=(0,1), figsize=(20,10), grid=True, xticks=range(0,401,10), title=txt_title)
accuracy_lines.plot([test_best_accuracy['epoch'].values[0]], [test_best_accuracy['accuracy'].values[0]], 'go', c='r')
accuracy_lines.plot([test_best_loss['epoch'].values[0]], [test_best_loss['loss'].values[0]], 'go', c='r')
accuracy_lines.axhline(test['accuracy'].mean(), color="red", linestyle="--")
accuracy_lines.axhline(test['loss'].mean(), color="red", linestyle="--")
#accuracy_lines.get_figure().savefig("{}/plot_200.png".format(training_dir))

#display(HTML(test_no_augmentation.to_html()))




x = pd.DataFrame(columns=('epoch', 'acc_train', 'acc_test', 'loss_train', 'loss_test'))
x['epoch'] = train['epoch'].to_numpy()
x['acc_train'] = train['accuracy'].to_numpy()
x['loss_train'] = train['loss'].to_numpy()
x['acc_test'] = test['accuracy'].to_numpy()
x['loss_test'] = test['loss'].to_numpy()
#print(x)

#print("Best accuracy: {}".format(test['accuracy'].max()))
#print("Mean accuracy: {}".format(test['accuracy'].mean()))
#print("Standard deviation: {}".format(test['accuracy'].std()))
#print("Best loss: {}".format(test['loss'].min()))
#print(test['accuracy'].size)

latex_csv_file_path = csv_file_path.replace(".csv", "__{}_512x512_latex.csv".format(transformation))
x.to_csv(latex_csv_file_path, encoding='utf-8', index=False)
# Out:
# 'random_8_operations' mean accuracy: 0.8506472427368164
# 'random_8_operations' standard deviation: 0.008346118289690218
# 'random_8_operations' best loss: 0.3035721261054277
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>augmentation</th>
#       <th>phase</th>
#       <th>epoch</th>
#       <th>loss</th>
#       <th>accuracy</th>
#       <th>date</th>
#       <th>transformations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2398</th>
#       <td>ORCA_512x512__Size-512x512_Epoch-400_Images-100_Batch-1__random_8_operations_all.pth</td>
#       <td>random_8_operations</td>
#       <td>train</td>
#       <td>400</td>
#       <td>0.163319</td>
#       <td>0.930689</td>
#       <td>2022-01-18 13:11:57.964414</td>
#       <td>[None 'horizontal_flip' 'vertical_flip' 'rotation' 'transpose' 'grid_distortion' 'optical_distortion' 'color_transfer' 'inpainting']</td>
#     </tr>
# ...

# %% [markdown]
# # qualitative

# %%
import os
import sys

current_path = os.path.abspath('.')
root_path = os.path.dirname(os.path.dirname(current_path))
sys.path.append(root_path)

from sourcecode.wsi_image_utils import *

threshold_prob = 0.50
threshold_itc = 200/(0.243 * pow(2, 5))

dir = "/home/dalifreire/Downloads/DataAugmentation/images"
results_dir = "{}/{}".format(dir, "results_orca_patch")


patch = "r2c5"
tma_image = "TCGA-CN-4726-01Z-00-DX1.0ddf44ae-1cb7-41f1-8b59-a5a689f5a71c_0"
patch_image = "{}/{}_{}.png".format(dir, tma_image, patch)
patch_image_mask = "{}/{}_{}_mask.png".format(dir, tma_image, patch)
patch_image_unet = "{}/{}_{}_unet.png".format(dir, tma_image, patch)
patch_image_segmented = "{}/{}_{}_segmented".format(dir, tma_image, patch)
patch_image_roi = "{}/{}_{}_roi".format(dir, tma_image, patch)

unet_pil_img = load_pil_image(patch_image_unet, gray=True)
unet_np_img = np.copy(pil_to_np(unet_pil_img))
unet_np_img = unet_np_img * (1.0/255)

segmented_np_img = basic_threshold(unet_np_img, threshold=threshold_prob, output_type="uint8")
predicted_labels = measure.label(segmented_np_img, connectivity=2)
predicted_np_img = np.zeros((segmented_np_img.shape[0], segmented_np_img.shape[1]))
labels = np.unique(predicted_labels)
properties = measure.regionprops(predicted_labels)
for lbl in range(1, np.max(labels)):
    major_axis_length = properties[lbl-1].major_axis_length
    if major_axis_length > threshold_itc:
        predicted_np_img[predicted_labels == lbl] = 1

segmented_pil_img = np_to_pil(predicted_np_img)
segmented_pil_img.save('{}/{}_{}_{}_segmented.png'.format(results_dir, "orca_patch", tma_image.split("-")[-1], patch))

load_pil_image(patch_image).save('{}/{}_{}_{}.png'.format(results_dir, "orca_patch", tma_image.split("-")[-1], patch))
load_pil_image(patch_image_mask, gray=True).save('{}/{}_{}_{}_mask.png'.format(results_dir, "orca_patch", tma_image.split("-")[-1], patch))
load_pil_image(patch_image_unet, gray=True).save('{}/{}_{}_{}_unet.png'.format(results_dir, "orca_patch", tma_image.split("-")[-1], patch))

patch_image_roi = blend_image(load_pil_image(patch_image), segmented_pil_img, foreground='red', inverse=True, alpha=0.5)
patch_image_roi.save('{}/{}_{}_{}_roi.png'.format(results_dir, "orca_patch", tma_image.split("-")[-1], patch))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-5ea2859350e6> in <module>
#      23 patch_image_roi = "{}/{}_{}_roi".format(dir, tma_image, patch)
#      24
# ---> 25 unet_pil_img = load_pil_image(patch_image_unet, gray=True)
#      26 unet_np_img = np.copy(pil_to_np(unet_pil_img))
#      27 unet_np_img = unet_np_img * (1.0/255)
#
# /media/dalifreire/DADOS1/PhD/github/tumor_regions_segmentation/sourcecode/wsi_image_utils.py in load_pil_image(path, gray, color_model)
#     285 def load_pil_image(path, gray=False, color_model="RGB"):
#     286
# --> 287     with open(path, 'rb') as f:
#     288
#     289         if gray:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/dalifreire/Downloads/DataAugmentation/images/TCGA-CN-4726-01Z-00-DX1.0ddf44ae-1cb7-41f1-8b59-a5a689f5a71c_0_r2c5_unet.png'

# %%
import os
import sys

current_path = os.path.abspath('.')
root_path = os.path.dirname(os.path.dirname(current_path))
sys.path.append(root_path)

from sourcecode.wsi_image_utils import *

threshold_prob = 0.50
threshold_itc = 200/(0.243 * pow(2, 5))

dir = "/home/dalifreire/Downloads/DataAugmentation/images"
results_dir = "{}/{}".format(dir, "results_orca_512x512")

#tma_image = "TCGA-CN-4726-01Z-00-DX1.0ddf44ae-1cb7-41f1-8b59-a5a689f5a71c_0_512x512"
#tma_image = "TCGA-CN-4726-01Z-00-DX1.0ddf44ae-1cb7-41f1-8b59-a5a689f5a71c_0_512x512"
tma_image = "TCGA-CN-4728-01Z-00-DX1.69fc04ce-cc6b-4c63-9322-b5ffb0056828_0_512x512"
patch_image = "{}/{}.png".format(dir, tma_image)
patch_image_mask = "{}/{}_mask.png".format(dir, tma_image)
patch_image_unet = "{}/{}_unet.png".format(dir, tma_image)
patch_image_segmented = "{}/{}_segmented".format(dir, tma_image)
patch_image_roi = "{}/{}_roi".format(dir, tma_image)

unet_pil_img = load_pil_image(patch_image_unet, gray=True)
unet_np_img = np.copy(pil_to_np(unet_pil_img))
unet_np_img = unet_np_img * (1.0/255)

segmented_np_img = basic_threshold(unet_np_img, threshold=threshold_prob, output_type="uint8")
predicted_labels = measure.label(segmented_np_img, connectivity=2)
predicted_np_img = np.zeros((segmented_np_img.shape[0], segmented_np_img.shape[1]))
labels = np.unique(predicted_labels)
properties = measure.regionprops(predicted_labels)
for lbl in range(1, np.max(labels)):
    major_axis_length = properties[lbl-1].major_axis_length
    if major_axis_length > threshold_itc:
        predicted_np_img[predicted_labels == lbl] = 1

segmented_pil_img = np_to_pil(predicted_np_img)
segmented_pil_img.save('{}/{}_{}_segmented.png'.format(results_dir, "orca_512x512", tma_image.split("-")[-1]))

load_pil_image(patch_image).save('{}/{}_{}.png'.format(results_dir, "orca_512x512", tma_image.split("-")[-1]))
load_pil_image(patch_image_mask, gray=True).save('{}/{}_{}_mask.png'.format(results_dir, "orca_512x512", tma_image.split("-")[-1]))
load_pil_image(patch_image_unet, gray=True).save('{}/{}_{}_unet.png'.format(results_dir, "orca_512x512", tma_image.split("-")[-1]))

patch_image_roi = blend_image(load_pil_image(patch_image), segmented_pil_img, foreground='red', inverse=True, alpha=0.5)
patch_image_roi.save('{}/{}_{}_roi.png'.format(results_dir, "orca_512x512", tma_image.split("-")[-1]))
