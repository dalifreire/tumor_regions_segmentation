# %% [markdown]
# # Instanciate the 'train', 'valid', and 'test' dataloaders

# %%
from orca_dataloader import *

dataset_dir = "../../datasets/ORCA"

batch_size = 6
patch_size = (640, 640)
color_model = "LAB"
dataloaders = create_dataloader(tile_size="{}x{}".format(patch_size[0], patch_size[1]),
                                batch_size=batch_size, 
                                shuffle=True,
                                img_input_size=patch_size,
                                img_output_size=patch_size,
                                dataset_dir=dataset_dir,
                                color_model=color_model, 
                                validation_split=0.2)

dataset_train_size = len(dataloaders['train'].dataset)
dataset_test_size = len(dataloaders['test'].dataset)
# Out:
# 2021-04-18 19:01:42,069 :: INFO load_dataset :: [training] ../../datasets/ORCA/training
# 2021-04-18 19:01:43,068 :: INFO load_dataset :: [training] ../../datasets/ORCA/training
# 2021-04-18 19:01:44,053 :: INFO load_dataset :: [testing] ../../datasets/ORCA/testing
# 2021-04-18 19:01:45,001 :: INFO create_dataloader :: Train images (640x640): 3344 (augmentation: True)
# 2021-04-18 19:01:45,003 :: INFO create_dataloader :: Validation images (640x640): 837 (augmentation: False)
# 2021-04-18 19:01:45,004 :: INFO create_dataloader :: Test images (640x640): 4481 (augmentation: False)

# %% [markdown]
# # Show some train images

# %%
dataset_show(dataloaders['train'], batch_size=batch_size, show_masks=True, row_limit=1)
# Out:
# 2021-04-18 19:03:35,184 :: INFO dataset_show :: Batch 1: 6/3344 images torch.Size([6, 3, 640, 640]) masks torch.Size([6, 640, 640])

# %% [markdown]
# # Show some validation images

# %%
dataset_show(dataloaders['valid'], batch_size=batch_size, show_masks=True, row_limit=1)
# Out:
# 2021-04-18 19:02:45,256 :: INFO dataset_show :: Batch 1: 6/837 images torch.Size([6, 3, 640, 640]) masks torch.Size([6, 640, 640])

# %% [markdown]
# # Show some test images

# %%
dataset_show(dataloaders['test'], batch_size=batch_size, show_masks=True, row_limit=1)
# Out:
# 2021-04-18 19:03:00,637 :: INFO dataset_show :: Batch 1: 6/4481 images torch.Size([6, 3, 640, 640]) masks torch.Size([6, 640, 640])
