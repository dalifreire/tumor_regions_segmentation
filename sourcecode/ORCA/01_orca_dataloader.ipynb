# %% [markdown]
# # Instanciate the 'train' and 'test' dataloaders

# %%
from orca_dataloader import *

dataset_dir = "../../datasets/ORCA"

batch_size = 6
patch_size = (640, 640)
color_model = "LAB"
dataloaders = create_dataloader(tile_size="{}x{}".format(patch_size[0], patch_size[1]),
                                batch_size=batch_size, 
                                shuffle=True,
                                img_input_size=patch_size,
                                img_output_size=patch_size,
                                dataset_dir=dataset_dir,
                                color_model=color_model)

dataset_train_size = len(dataloaders['train'].dataset)
dataset_test_size = len(dataloaders['test'].dataset)
# Out:
# 2021-02-01 17:30:07,184 :: INFO load_dataset :: [training] ../../datasets/ORCA/training
# 2021-02-01 17:30:08,217 :: INFO load_dataset :: [testing] ../../datasets/ORCA/testing
# 2021-02-01 17:30:09,195 :: INFO create_dataloader :: Train images (640x640): 4181 (augmentation: True)
# 2021-02-01 17:30:09,196 :: INFO create_dataloader :: Test images (640x640): 4481 (augmentation: False)

# %% [markdown]
# # Show some train images

# %%
dataset_show(dataloaders['train'], batch_size=batch_size, show_masks=True, row_limit=1)
# Out:
# 2021-02-01 17:30:14,068 :: INFO dataset_show :: Batch 1: 6/4181 images torch.Size([6, 3, 640, 640]) masks torch.Size([6, 640, 640])

# %% [markdown]
# # Show some test images

# %%
dataset_show(dataloaders['test'], batch_size=batch_size, show_masks=True, row_limit=1)
# Out:
# 2021-02-01 17:30:18,393 :: INFO dataset_show :: Batch 1: 6/4481 images torch.Size([6, 3, 640, 640]) masks torch.Size([6, 640, 640])
