# %% [markdown]
# # Instanciate the 'train' and 'test' dataloaders

# %%
from camelyon16_dataloader import *

dataset_dir = "../../datasets/CAMELYON16"

batch_size = 6
patch_size = (640, 640)
color_model = "LAB"
dataloaders = create_dataloader(tile_size="{}x{}".format(patch_size[0], patch_size[1]),
                                batch_size=batch_size, 
                                shuffle=True,
                                img_input_size=patch_size,
                                img_output_size=patch_size,
                                dataset_dir=dataset_dir,
                                color_model=color_model)

dataset_train_size = len(dataloaders['train'].dataset)
dataset_test_size = len(dataloaders['test'].dataset)
# Out:
# 2020-12-26 12:19:50,280 :: INFO load_dataset :: [training] ../../datasets/CAMELYON16/training
# 2020-12-26 12:19:50,303 :: INFO load_dataset :: [testing] ../../datasets/CAMELYON16/testing
# 2020-12-26 12:19:50,336 :: INFO create_dataloader :: Train images (640x640): 10 (augmentation: True)
# 2020-12-26 12:19:50,338 :: INFO create_dataloader :: Test images (640x640): 10 (augmentation: False)

# %% [markdown]
# # Show some train images

# %%
dataset_show(dataloaders['train'], batch_size=batch_size, show_masks=True, row_limit=1)
# Out:
# 2020-12-26 12:20:13,472 :: INFO dataset_show :: Batch 1: 6/10 images torch.Size([6, 3, 640, 640]) masks torch.Size([6, 640, 640])

# %% [markdown]
# # Show some test images

# %%
dataset_show(dataloaders['test'], batch_size=batch_size, show_masks=True, row_limit=1)
# Out:
# 2020-12-26 12:21:14,055 :: INFO dataset_show :: Batch 1: 6/10 images torch.Size([6, 3, 640, 640]) masks torch.Size([6, 640, 640])
